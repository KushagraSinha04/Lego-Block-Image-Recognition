# %%
#Mounting Google Drive to Colab
#This will open a link with a code : Copy paste that code in the output window
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Change Working Directory to the uploaded Darknet Folder
# %cd "/content/drive/My Drive/darknet-master_orientation/"
# Out:
# /content/drive/My Drive/darknet-master_orientation

# %%
#Compiling Darknet
# !make
# !chmod +x ./darknet
# Out:
# chmod +x *.sh

# %%
#Converting few files to Unix format
# !sudo apt install dos2unix
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   dos2unix
# 0 upgraded, 1 newly installed, 0 to remove and 14 not upgraded.
# Need to get 351 kB of archives.
# After this operation, 1,267 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 dos2unix amd64 7.3.4-3 [351 kB]
# Fetched 351 kB in 2s (216 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package dos2unix.
# ...

# %%
# !dos2unix ./data/train.txt
# !dos2unix ./data/obj.data
# !dos2unix ./data/obj.names
# !dos2unix ./cfg/yolo-obj.cfg
# Out:
# dos2unix: converting file ./data/train.txt to Unix format...
# dos2unix: converting file ./data/obj.data to Unix format...
# dos2unix: converting file ./data/obj.names to Unix format...
# dos2unix: converting file ./cfg/yolo-obj.cfg to Unix format...

# %%
#Training Starts with the following line: It takes more than few days. Colab Disconnects after 12 hours
! ./darknet detector train data/obj.data cfg/yolo-obj.cfg yolov4.conv.137 -dont_show

# %%
#When Colab Disconnects : Resume training using below line
#A backup folder will be created under darknet folder. From that use the latest weight file.Replace 1000 with latest weight 
# !./darknet detector train data/obj.data cfg/yolo-obj.cfg backup/yolo-obj_1000.weights -dont_show

# %%
# !./darknet detector train data/obj.data cfg/yolo-obj.cfg backup/yolo-obj_last.weights -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  3380: 2.935619, 3.088042 avg loss, 0.001000 rate, 3.246608 seconds, 216320 images, 13.331468 hours left
# Resizing, random_coef = 1.40
#
#  384 x 384
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 6.155015 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.807922, GIOU: 0.801692), Class: 0.999477, Obj: 0.898692, No Obj: 0.000318, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.082064, iou_loss = 1.428738, total_loss = 1.510802
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.794974, GIOU: 0.788829), Class: 0.967984, Obj: 0.847132, No Obj: 0.013959, .5R: 1.000000, .75R: 0.745455, count: 55, class_loss = 1.514568, iou_loss = 10.159867, total_loss = 11.674436
# ...

# %%
#To test the image : Change the file to latest weights from backup folder
#When this runs : In output : Enter the location of the file in google drive. For that image a new prediction image will be created with bounding boxes
# !./darknet detector test data/obj.data cfg/yolo-obj.cfg backup/yolo-obj_last.weights
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    3 route  1 		                           ->  208 x 208 x  64
#    4 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    5 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    6 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
# ...

# %%
#To get the path of test images, for inserting in the above line
# !ls "/content/drive/My Drive/Check/1 (20).jpg"
# Out:
# '/content/drive/My Drive/Check/1 (20).jpg'
